# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
path = "pydata-book/ch02/usagov_bitly_data2012-03-16-1331923249.txt"
records = [json.loads(line) for line in open(path)] # open the "path" file and read lines by JSON loader

# %%
records[0]
# Out:
# {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#  u'al': u'en-US,en;q=0.8',
#  u'c': u'US',
#  u'cy': u'Danvers',
#  u'g': u'A6qOVH',
#  u'gr': u'MA',
#  u'h': u'wfLQtf',
#  u'hc': 1331822918,
#  u'hh': u'1.usa.gov',
#  u'l': u'orofrog',
#  u'll': [42.576698, -70.954903],
#  u'nk': 1,
#  u'r': u'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#  u't': 1331923247,
#  u'tz': u'America/New_York',
#  u'u': u'http://www.ncbi.nlm.nih.gov/pubmed/22415991'}

# %%
records[0,tz] # you can use symbols as a index of arrays!!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-1b8530ff2d1d> in <module>()
# ----> 1 records[0,tz] # you can use symbols as a index of arrays!!
#
# NameError: name 'tz' is not defined

# %%
records[0,'tz'] # you know this is not numpy array.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-3d6dfb24f077> in <module>()
# ----> 1 records[0,'tz'] # you know this is not numpy array.
#
# TypeError: list indices must be integers, not tuple

# %%
records[0]['tz'] # a raw value
# Out:
# u'America/New_York'

# %%
print records[0]['tz'] # so print interpret the input as String
# Out:
# America/New_York

# %%
time_zones = [rec['tz'] for rec in records] # for all elements in records, list 'tz' entries
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-7f5c34a9d370> in <module>()
# ----> 1 time_zones = [rec['tz'] for rec in records] # for all elements in records, list 'tz' entries
#
# KeyError: 'tz'

# %%
time_zones = [rec['tz'] for rec in records if 'tz' in rec ] # for all elements who has 'tz' entry, list 'tz' entries

# %%
time_zones[:10]
# Out:
# [u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'',
#  u'',
#  u'']

# %%
def get_counts(sequence):
    counts = []
    for x in sequence:
        if x in counts:
            counts[x] += 1
        else:
            counts[x] = 1 
    return conuts
# end get_counts

from collections import defaultdict
def get_counts2(sequence):
    counts = defaultdict(int) # values will initialize to -
    for x in sequence:
        counts[x] += 1
    # end for
    return counts
# end get_counts2

# %%
counts = get_counts2(time_zones)
counts['America/New_York']
# Out:
# 1251

# %%
len(time_zones)
# Out:
# 3440

# %%
def top_counts(count_dict, n=10):
    value_key_pairs = [(count, tz) for tz, count in count_dict.items()]
    value_key_pairs.sort()
    return value_key_pairs[-n:] # this is inverted
# end top_counts

top_counts(counts)
# Out:
# [(33, u'America/Sao_Paulo'),
#  (35, u'Europe/Madrid'),
#  (36, u'Pacific/Honolulu'),
#  (37, u'Asia/Tokyo'),
#  (74, u'Europe/London'),
#  (191, u'America/Denver'),
#  (382, u'America/Los_Angeles'),
#  (400, u'America/Chicago'),
#  (521, u''),
#  (1251, u'America/New_York')]

# %%
top_counts(counts, 14)
# Out:
# [(22, u'Europe/Amsterdam'),
#  (25, u'America/Rainy_River'),
#  (27, u'Europe/Rome'),
#  (28, u'Europe/Berlin'),
#  (33, u'America/Sao_Paulo'),
#  (35, u'Europe/Madrid'),
#  (36, u'Pacific/Honolulu'),
#  (37, u'Asia/Tokyo'),
#  (74, u'Europe/London'),
#  (191, u'America/Denver'),
#  (382, u'America/Los_Angeles'),
#  (400, u'America/Chicago'),
#  (521, u''),
#  (1251, u'America/New_York')]

# %%
from collections import Counter # Ah, this is convenient counter class. 
counts = Counter(time_zones)
counts.most_common(10)
# Out:
# [(u'America/New_York', 1251),
#  (u'', 521),
#  (u'America/Chicago', 400),
#  (u'America/Los_Angeles', 382),
#  (u'America/Denver', 191),
#  (u'Europe/London', 74),
#  (u'Asia/Tokyo', 37),
#  (u'Pacific/Honolulu', 36),
#  (u'Europe/Madrid', 35),
#  (u'America/Sao_Paulo', 33)]

# %%
from pandas import DataFrame, Series
frame = DataFrame(records) # Wow! what'a nice table! so 
frame
# Out:
#     _heartbeat_                                                  a  \
# 0           NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1           NaN                             GoogleMaps/RochesterNY
# 2           NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3           NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4           NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 5           NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6           NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 7           NaN  Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/2...
# 8           NaN  Opera/9.80 (X11; Linux zbov; U; en) Presto/2.1...
# 9           NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 10          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# 11          NaN  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4...
# 12          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# 13   1331923261                                                NaN
# 14          NaN  Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US...
# 15          NaN  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1...
# 16          NaN  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1...
# 17          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.5; r...
# 18          NaN                             GoogleMaps/RochesterNY
# 19          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 20          NaN  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 21          NaN  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.6...
# 22          NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 23          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3)...
# 24          NaN  Mozilla/5.0 (Windows; U; Windows NT 5.1; es-ES...
# 25          NaN  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1...
# 26          NaN  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1...
# 27          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 28          NaN  Mozilla/5.0 (iPad; CPU OS 5_0_1 like Mac OS X)...
# 29          NaN  Mozilla/5.0 (iPad; U; CPU OS 3_2 like Mac OS X...
# 30          NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 31          NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 32          NaN  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...
# 33          NaN  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4...
# 34          NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 35          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 36          NaN  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...
# 37          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# 38          NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 39          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# 40          NaN  Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Ma...
# 41          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# 42          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 43          NaN  Mozilla/5.0 (Windows NT 6.1; rv:9.0.1) Gecko/2...
# 44          NaN  Mozilla/5.0 (iPhone; CPU iPhone OS 5_0_1 like ...
# 45          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; r...
# 46          NaN  BlackBerry8520/5.0.0.592 Profile/MIDP-2.1 Conf...
# 47          NaN  Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US...
# 48          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:9.0.1) ...
# 49          NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 50          NaN  Mozilla/5.0 (Windows NT 5.1; rv:10.0.2) Gecko/...
# 51          NaN  Mozilla/5.0 (Linux; U; Android 2.2.2; en-us; L...
# 52          NaN  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1...
# 53          NaN  Mozilla/5.0 (compatible; MSIE 9.0; Windows Pho...
# 54          NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 55   1331923291                                                NaN
# 56          NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 57          NaN  Mozilla/5.0 (iPhone; U; CPU iPhone OS 5_0_1 li...
# 58          NaN  Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Ma...
# 59          NaN  Mozilla/5.0 (iPhone; CPU iPhone OS 5_1 like Ma...
#             ...                                                ...
#
#                                         al     c                cy       g  \
# 0                           en-US,en;q=0.8    US           Danvers  A6qOVH
# 1                                      NaN    US             Provo  mwszkS
# 2                                    en-US    US        Washington  xxr3Qb
# 3                                    pt-br    BR              Braz  zCaLwp
# 4                           en-US,en;q=0.8    US        Shrewsbury  9b6kNl
# 5                           en-US,en;q=0.8    US        Shrewsbury  axNK8c
# 6      pl-PL,pl;q=0.8,en-US;q=0.6,en;q=0.4    PL             Luban  wcndER
# 7                  bg,en-us;q=0.7,en;q=0.3  None               NaN  wcndER
# 8                                en-US, en  None               NaN  wcndER
# 9      pt-BR,pt;q=0.8,en-US;q=0.6,en;q=0.4  None               NaN  zCaLwp
# 10                          en-us,en;q=0.5    US           Seattle  vNJS4H
# 11                          en-us,en;q=0.5    US        Washington  wG7OIH
# 12                          en-us,en;q=0.5    US        Alexandria  vNJS4H
# 13                                     NaN   NaN               NaN     NaN
# 14                          en-us,en;q=0.5    US          Marietta  2rOUYc
# 15     zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4    HK  Central District  nQvgJp
# 16     zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4    HK  Central District   XdUNr
# 17                          en-us,en;q=0.5    US         Buckfield  zH1BFf
# 18                                     NaN    US             Provo  mwszkS
# 19     it-IT,it;q=0.8,en-US;q=0.6,en;q=0.4    IT            Venice  wcndER
# 20                                   es-ES    ES             Alcal  zQ95Hi
# 21                          en-us,en;q=0.5    US     Davidsonville  wcndER
# 22                                   en-us    US         Hockessin  y3ZImz
# 23                                   en-us    US            Lititz  wWiOiD
# 24     es-es,es;q=0.8,en-us;q=0.5,en;q=0.3    ES            Bilbao  wcndER
# 25  en-GB,en;q=0.8,en-US;q=0.6,en-AU;q=0.4    MY      Kuala Lumpur  wcndER
# 26     ro-RO,ro;q=0.8,en-US;q=0.6,en;q=0.4    CY           Nicosia  wcndER
# 27                          en-US,en;q=0.8    BR            SPaulo  zCaLwp
# 28                                   en-us  None               NaN  vNJS4H
# 29                                   en-us  None               NaN  FPX0IM
# 30              en-GB,en-US;q=0.8,en;q=0.6    GB      Huddersfield  wcndER
# 31                          en-US,en;q=0.8    US          Fairport  wcndER
# 32                                   en-us    US          Honolulu  FO8qn8
# 33                          en-us,en;q=0.5    US         Knoxville  y5uuLa
# 34                          en-US,en;q=0.8  None               NaN  wcndER
# 35                          en-US,en;q=0.8  None               NaN  xOsMcy
# 36                                   en-us    US          Honolulu  FO8qn8
# 37                          en-us,en;q=0.5  None               NaN  vNJS4H
# 38                                   en-us    US        Washington  wmAjaQ
# 39                          en-us,en;q=0.5    US          Stamford  vNJS4H
# 40                                   en-us    US             Bronx    BNDz
# 41                          en-us,en;q=0.5    US       Saint Louis  wWiOiD
# 42     it-IT,it;q=0.8,en-US;q=0.6,en;q=0.4    IT              Rome  wcndER
# 43                          en-us,en;q=0.5    US            Dudley  vNJS4H
# 44                                   en-us    US             Bowie  16aNQi
# 45                          en-us,en;q=0.5    US       Los Angeles  vNJS4H
# 46                                      en  None               NaN  yD1K8w
# 47                          en-us,en;q=0.5  None               NaN  wcndER
# 48                          en-us,en;q=0.5    US          Savannah  vNJS4H
# 49                                   en-US    US        Washington  znwhw1
# 50                          en-gb,en;q=0.5    MT            Sliema  wcndER
# 51                                   en-US    US        Woodbridge  wcndER
# 52                          en-US,en;q=0.8    US      Grand Rapids  FO8od2
# 53                                   en-IN  None               NaN  wcndER
# 54                                   en-us    US       Chula Vista  FOogtm
# 55                                     NaN   NaN               NaN     NaN
# 56     pt-BR,pt;q=0.8,en-US;q=0.6,en;q=0.4    BR          Curitiba  zCaLwp
# 57                                   en-us  None               NaN  wcndER
# 58                                   en-us    HK  Central District   XdUNr
# 59                                   en-us    HK  Central District  nQvgJp
#                                        ...   ...               ...     ...
#
#      gr       h          hc           hh          kw                l  \
# 0    MA  wfLQtf  1331822918    1.usa.gov         NaN          orofrog
# 1    UT  mwszkS  1308262393         j.mp         NaN            bitly
# 2    DC  xxr3Qb  1331919941    1.usa.gov         NaN            bitly
# 3    27  zUtuOu  1331923068    1.usa.gov         NaN         alelex88
# 4    MA  9b6kNl  1273672411       bit.ly         NaN            bitly
# 5    MA  axNK8c  1273672506       bit.ly         NaN            bitly
# 6    77  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 7   NaN  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 8   NaN  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 9   NaN  zUtuOu  1331923068    1.usa.gov         NaN         alelex88
# 10   WA  u0uD9q  1319563556    1.usa.gov         NaN     o_4us71ccioa
# 11   DC  A0nRz4  1331815838    1.usa.gov         NaN      darrellissa
# 12   VA  u0uD9q  1319563556    1.usa.gov         NaN     o_4us71ccioa
# 13  NaN     NaN         NaN          NaN         NaN              NaN
# 14   GA  2rOUYc  1255769846    1.usa.gov         NaN            bitly
# 15   00  rtrrth  1317318030         j.mp         NaN       walkeryuen
# 16   00  qWkgbq  1317318039         j.mp         NaN       walkeryuen
# 17   ME  x3jOIv  1331839576    1.usa.gov         NaN    andyzieminski
# 18   UT  mwszkS  1308262393    1.usa.gov         NaN            bitly
# 19   20  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 20   51  ytZYWR  1331670549    bitly.com         NaN          jplnews
# 21   MD  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 22   DE  y3ZImz  1331064158    1.usa.gov         NaN            bitly
# 23   PA  wWiOiD  1330217829    1.usa.gov         NaN            bitly
# 24   59  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 25   14  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 26   04  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 27   27  zUtuOu  1331923068    1.usa.gov         NaN         alelex88
# 28  NaN  u0uD9q  1319563556    1.usa.gov         NaN     o_4us71ccioa
# 29  NaN  FPX0IL  1331922978    1.usa.gov         NaN     twittershare
# 30   G8  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 31   NY  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 32   HI  zGDswc  1331922709       bit.ly  SBXreturns          kcatian
# 33   TN  AfJNSd  1331825200  go.nasa.gov         NaN      nasatwitter
# 34  NaN  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 35  NaN  yV8hww  1331829147    1.usa.gov         NaN           wwpinc
# 36   HI  zGDswc  1331922709    1.usa.gov  SBXreturns          kcatian
# 37  NaN  u0uD9q  1319563556    1.usa.gov         NaN     o_4us71ccioa
# 38   DC  z6glLT  1331665443    1.usa.gov         NaN     citizencorps
# 39   CT  u0uD9q  1319563556    1.usa.gov         NaN     o_4us71ccioa
# 40   NY  14Q1q3  1246975140    1.usa.gov         NaN     tweetdeckapi
# 41   MO  wWiOiD  1330217829    1.usa.gov         NaN            bitly
# 42   07  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 43   MA  u0uD9q  1319563556    1.usa.gov         NaN     o_4us71ccioa
# 44   MD  xoB0ID  1328745636    1.usa.gov         NaN       usagovteam
# 45   CA  u0uD9q  1319563556    1.usa.gov         NaN     o_4us71ccioa
# 46  NaN  AAEmdT  1331756442    1.usa.gov         NaN         healthit
# 47  NaN  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 48   GA  u0uD9q  1319563556    1.usa.gov         NaN     o_4us71ccioa
# 49   DC  xurm7e  1331853485    1.usa.gov         NaN    aashtojournal
# 50   00  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 51   VA  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 52   MI  FO8od1  1331921833        ds.io         NaN  developmentseed
# 53  NaN  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 54   CA  AkgL2C  1331920879    1.usa.gov         NaN      twitterfeed
# 55  NaN     NaN         NaN          NaN         NaN              NaN
# 56   18  zUtuOu  1331923068    1.usa.gov         NaN         alelex88
# 57  NaN  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
# 58   00  qWkgbq  1317318039         j.mp         NaN       walkeryuen
# 59   00  rtrrth  1317318030         j.mp         NaN       walkeryuen
#     ...     ...         ...          ...         ...              ...
#
#                           ll  nk  \
# 0    [42.576698, -70.954903]   1
# 1   [40.218102, -111.613297]   0
# 2      [38.9007, -77.043098]   1
# 3   [-23.549999, -46.616699]   0
# 4    [42.286499, -71.714699]   0
# 5    [42.286499, -71.714699]   0
# 6       [51.116699, 15.2833]   0
# 7                        NaN   0
# 8                        NaN   0
# 9                        NaN   0
# 10    [47.5951, -122.332603]   1
# 11   [38.937599, -77.092796]   0
# 12   [38.790901, -77.094704]   1
# 13                       NaN NaN
# 14     [33.953201, -84.5177]   1
# 15     [22.2833, 114.150002]   1
# 16     [22.2833, 114.150002]   1
# 17   [44.299702, -70.369797]   0
# 18  [40.218102, -111.613297]   0
# 19      [45.438599, 12.3267]   0
# 20      [37.516701, -5.9833]   0
# 21   [38.939201, -76.635002]   0
# 22      [39.785, -75.682297]   0
# 23     [40.174999, -76.3078]   0
# 24          [43.25, -2.9667]   0
# 25      [3.1667, 101.699997]   0
# 26    [35.166698, 33.366699]   0
# 27    [-23.5333, -46.616699]   0
# 28                       NaN   0
# 29                       NaN   1
# 30      [53.650002, -1.7833]   0
# 31   [43.100498, -77.426003]   0
# 32    [21.3139, -157.824493]   1
# 33   [35.972401, -83.959503]   1
# 34                       NaN   1
# 35                       NaN   0
# 36    [21.3139, -157.824493]   1
# 37                       NaN   1
# 38   [38.897099, -77.040901]   0
# 39   [41.097801, -73.518799]   1
# 40     [40.849899, -73.8769]   0
# 41     [38.6143, -90.444397]   0
# 42      [41.900002, 12.4833]   0
# 43     [42.059399, -71.9356]   1
# 44     [38.9576, -76.756599]   1
# 45  [34.065701, -118.436203]   1
# 46                       NaN   0
# 47                       NaN   0
# 48     [31.997101, -80.9645]   1
# 49   [38.909698, -77.023102]   0
# 50      [35.912498, 14.5019]   0
# 51   [38.625702, -77.266502]   0
# 52   [42.977699, -85.710999]   1
# 53                       NaN   0
# 54    [32.636101, -117.0532]   1
# 55                       NaN NaN
# 56        [-25.4167, -49.25]   0
# 57                       NaN   0
# 58     [22.2833, 114.150002]   0
# 59     [22.2833, 114.150002]   0
#                          ... ...
#
#                                                     r           t  \
# 0   http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/...  1331923247
# 1                            http://www.AwareMap.com/  1331923249
# 2                                http://t.co/03elZC4Q  1331923250
# 3                                              direct  1331923249
# 4                 http://www.shrewsbury-ma.gov/selco/  1331923251
# 5                 http://www.shrewsbury-ma.gov/selco/  1331923252
# 6   http://plus.url.google.com/url?sa=z&n=13319232...  1331923255
# 7                            http://www.facebook.com/  1331923255
# 8   http://www.facebook.com/l.php?u=http%3A%2F%2F1...  1331923254
# 9                                http://t.co/o1Pd0WeV  1331923255
# 10                                             direct  1331923258
# 11                               http://t.co/ND7SoPyo  1331923259
# 12                                             direct  1331923259
# 13                                                NaN         NaN
# 14                                             direct  1331923262
# 15  http://forum2.hkgolden.com/view.aspx?type=BW&m...  1331923263
# 16  http://forum2.hkgolden.com/view.aspx?type=BW&m...  1331923263
# 17                               http://t.co/6Cx4ROLs  1331923264
# 18                           http://www.AwareMap.com/  1331923262
# 19                           http://www.facebook.com/  1331923264
# 20                           http://www.facebook.com/  1331923265
# 21                           http://www.facebook.com/  1331923267
# 22                                             direct  1331923267
# 23  http://www.facebook.com/l.php?u=http%3A%2F%2F1...  1331923267
# 24                           http://www.facebook.com/  1331923268
# 25                           http://www.facebook.com/  1331923269
# 26               http://www.facebook.com/?ref=tn_tnmn  1331923268
# 27                                             direct  1331923269
# 28                                             direct  1331923270
# 29                               http://t.co/5xlp0B34  1331923270
# 30  http://plus.url.google.com/url?sa=z&n=13319233...  1331923271
# 31  http://www.facebook.com/l.php?u=http%3A%2F%2F1...  1331923271
# 32                                             direct  1331923276
# 33                               http://t.co/1ghGl5Pl  1331923275
# 34  http://plus.url.google.com/url?sa=z&n=13319232...  1331923276
# 35  http://www.facebook.com/l.php?u=http%3A%2F%2F1...  1331923277
# 36                                             direct  1331923278
# 37                                             direct  1331923278
# 38                                             direct  1331923279
# 39                                             direct  1331923279
# 40                                             direct  1331923279
# 41  http://www.facebook.com/l.php?u=http%3A%2F%2F1...  1331923281
# 42  http://www.facebook.com/l.php?u=http%3A%2F%2F1...  1331923280
# 43                                             direct  1331923281
# 44                                             direct  1331923281
# 45                                             direct  1331923284
# 46                  http://mobile.twitter.com/AIDSgov  1331923284
# 47                  http://www.facebook.com/home.php?  1331923286
# 48                                             direct  1331923284
# 49  http://www.aashtojournal.org/Pages/031612senat...  1331923285
# 50  http://www.facebook.com/l.php?u=http%3A%2F%2F1...  1331923288
# 51  http://m.facebook.com/l.php?u=http%3A%2F%2F1.u...  1331923288
# 52                               http://t.co/wgctD0rd  1331923287
# 53                                             direct  1331923287
# 54                               http://t.co/ovz0wT2O  1331923291
# 55                                                NaN         NaN
# 56                               http://t.co/o1Pd0WeV  1331923292
# 57  http://m.facebook.com/l.php?u=http%3A%2F%2F1.u...  1331923293
# 58  http://lalaf.com/ihkg/app/iphone.4_71.php?gif=...  1331923292
# 59  http://lalaf.com/ihkg/app/iphone.4_71.php?gif=...  1331923292
#                                                   ...         ...
#
#                      tz                                                  u
# 0      America/New_York        http://www.ncbi.nlm.nih.gov/pubmed/22415991
# 1        America/Denver        http://www.monroecounty.gov/etc/911/rss.php
# 2      America/New_York  http://boxer.senate.gov/en/press/releases/0316...
# 3     America/Sao_Paulo            http://apod.nasa.gov/apod/ap120312.html
# 4      America/New_York  http://www.shrewsbury-ma.gov/egov/gallery/1341...
# 5      America/New_York  http://www.shrewsbury-ma.gov/egov/gallery/1341...
# 6         Europe/Warsaw  http://www.nasa.gov/mission_pages/nustar/main/...
# 7                        http://www.nasa.gov/mission_pages/nustar/main/...
# 8                        http://www.nasa.gov/mission_pages/nustar/main/...
# 9                                  http://apod.nasa.gov/apod/ap120312.html
# 10  America/Los_Angeles  https://www.nysdot.gov/rexdesign/design/commun...
# 11     America/New_York  http://oversight.house.gov/wp-content/uploads/...
# 12     America/New_York  https://www.nysdot.gov/rexdesign/design/commun...
# 13                  NaN                                                NaN
# 14     America/New_York               http://toxtown.nlm.nih.gov/index.php
# 15       Asia/Hong_Kong  http://www.ssd.noaa.gov/PS/TROP/TCFP/data/curr...
# 16       Asia/Hong_Kong  http://www.usno.navy.mil/NOOC/nmfc-ph/RSS/jtwc...
# 17     America/New_York  http://www.usda.gov/wps/portal/usda/usdahome?c...
# 18       America/Denver        http://www.monroecounty.gov/etc/911/rss.php
# 19          Europe/Rome  http://www.nasa.gov/mission_pages/nustar/main/...
# 20         Africa/Ceuta  http://voyager.jpl.nasa.gov/imagesvideo/uranus...
# 21     America/New_York  http://www.nasa.gov/mission_pages/nustar/main/...
# 22     America/New_York  http://portal.hud.gov/hudportal/documents/hudd...
# 23     America/New_York  http://www.tricare.mil/mybenefit/ProfileFilter...
# 24        Europe/Madrid  http://www.nasa.gov/mission_pages/nustar/main/...
# 25    Asia/Kuala_Lumpur  http://www.nasa.gov/mission_pages/nustar/main/...
# 26         Asia/Nicosia  http://www.nasa.gov/mission_pages/nustar/main/...
# 27    America/Sao_Paulo            http://apod.nasa.gov/apod/ap120312.html
# 28                       https://www.nysdot.gov/rexdesign/design/commun...
# 29                       http://www.ed.gov/news/media-advisories/us-dep...
# 30        Europe/London  http://www.nasa.gov/mission_pages/nustar/main/...
# 31     America/New_York  http://www.nasa.gov/mission_pages/nustar/main/...
# 32     Pacific/Honolulu  http://www.cnic.navy.mil/navycni/groups/public...
# 33      America/Chicago  http://www.nasa.gov/topics/earth/features/2012...
# 34                       http://www.nasa.gov/mission_pages/nustar/main/...
# 35                       http://www.army.mil/article/75464/Marksmanship...
# 36     Pacific/Honolulu  http://www.cnic.navy.mil/navycni/groups/public...
# 37                       https://www.nysdot.gov/rexdesign/design/commun...
# 38     America/New_York  http://citizencorps.gov/getstarted/youth/youth...
# 39     America/New_York  https://www.nysdot.gov/rexdesign/design/commun...
# 40     America/New_York  http://radar.weather.gov/Conus/northeast_loop.php
# 41      America/Chicago  http://www.tricare.mil/mybenefit/ProfileFilter...
# 42          Europe/Rome  http://www.nasa.gov/mission_pages/nustar/main/...
# 43     America/New_York  https://www.nysdot.gov/rexdesign/design/commun...
# 44     America/New_York  http://www.irs.gov/individuals/article/0,,id=9...
# 45  America/Los_Angeles  https://www.nysdot.gov/rexdesign/design/commun...
# 46                       http://www.hhs.gov/live/?utm_source=ketchum&ut...
# 47                       http://www.nasa.gov/mission_pages/nustar/main/...
# 48     America/New_York  https://www.nysdot.gov/rexdesign/design/commun...
# 49     America/New_York  http://www.senate.gov/legislative/LIS/roll_cal...
# 50         Europe/Malta  http://www.nasa.gov/mission_pages/nustar/main/...
# 51     America/New_York  http://www.nasa.gov/mission_pages/nustar/main/...
# 52     America/New_York  http://www.nature.nps.gov/features/eclipse/whe...
# 53                       http://www.nasa.gov/mission_pages/nustar/main/...
# 54  America/Los_Angeles  http://www.whitehouse.gov/the-press-office/201...
# 55                  NaN                                                NaN
# 56    America/Sao_Paulo            http://apod.nasa.gov/apod/ap120312.html
# 57                       http://www.nasa.gov/mission_pages/nustar/main/...
# 58       Asia/Hong_Kong  http://www.usno.navy.mil/NOOC/nmfc-ph/RSS/jtwc...
# 59       Asia/Hong_Kong  http://www.ssd.noaa.gov/PS/TROP/TCFP/data/curr...
#                     ...                                                ...
#
# [3560 rows x 18 columns]

# %%
frame['tz'][:10] # this is called Series
# Out:
# 0     America/New_York
# 1       America/Denver
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# 5     America/New_York
# 6        Europe/Warsaw
# 7
# 8
# 9
# Name: tz, dtype: object

# %%
tz_counts = frame['tz'].value_counts()
tz_counts[:10]
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# dtype: int64

# %%
clean_tz = frame['tz'].fillna('Missing') # fill all missing entries with "Missing"
clean_tz[clean_tz == ''] = 'Unknown' #
tz_counts = clean_tz.value_counts()
tz_counts[:10]
# Out:
# America/New_York       1251
# Unknown                 521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# dtype: int64

# %%
tz_counts[:10].plot(kind='barh', rot=0)

# %%
frame['a'][1]
# Out:
# u'GoogleMaps/RochesterNY'

# %%
frame['a'][51]
# Out:
# u'Mozilla/5.0 (Linux; U; Android 2.2.2; en-us; LG-P925/V10e Build/FRG83G) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1'

# %%
results=Series([x.split()[0] for x in frame.a.dropna()])
results[:5]
# Out:
# 0               Mozilla/5.0
# 1    GoogleMaps/RochesterNY
# 2               Mozilla/4.0
# 3               Mozilla/5.0
# 4               Mozilla/5.0
# dtype: object

# %%
print results.shape
# Out:
# (3440,)

# %%
results.value_counts()[:10]
# Out:
# Mozilla/5.0                 2594
# Mozilla/4.0                  601
# GoogleMaps/RochesterNY       121
# Opera/9.80                    34
# TEST_INTERNET_AGENT           24
# GoogleProducer                21
# Mozilla/6.0                    5
# BlackBerry8520/5.0.0.681       4
# Dalvik/1.4.0                   3
# BlackBerry8520/5.0.0.592       3
# dtype: int64

# %%
cframe=frame[frame.a.notnull()] # note Frame is pandas strucure, but seemleslly Numpy
cframe.shape
# Out:
# (3440, 18)

# %%
operating_system = np.where( cframe['a'].str.contains('Windows'),'windows','Not Windows' ) # contains might be a Frame function
operating_system[:5]
# Out:
# array(['windows', 'Not Windows', 'windows', 'Not Windows', 'windows'],
#       dtype='|S11')

# %%
by_tz_os = cframe.groupby(['tz', operating_system]) # panads.core.groupby.DataFrameGroupBy data

# %%
type(by_tz_os)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
by_tz_os.size() # Ah, so return the unique sets and its frequency
# Out:
# tz
#                                 Not Windows    245
#                                 windows        276
# Africa/Cairo                    windows          3
# Africa/Casablanca               windows          1
# Africa/Ceuta                    windows          2
# Africa/Johannesburg             windows          1
# Africa/Lusaka                   windows          1
# America/Anchorage               Not Windows      4
#                                 windows          1
# America/Argentina/Buenos_Aires  Not Windows      1
# America/Argentina/Cordoba       windows          1
# America/Argentina/Mendoza       windows          1
# America/Bogota                  Not Windows      1
#                                 windows          2
# America/Caracas                 windows          1
# ...
# Europe/Skopje     windows         1
# Europe/Sofia      windows         1
# Europe/Stockholm  Not Windows     2
#                   windows        12
# Europe/Uzhgorod   windows         1
# Europe/Vienna     Not Windows     3
#                   windows         3
# Europe/Vilnius    windows         2
# Europe/Volgograd  windows         1
# Europe/Warsaw     Not Windows     1
#                   windows        15
# Europe/Zurich     Not Windows     4
# Pacific/Auckland  Not Windows     3
#                   windows         8
# Pacific/Honolulu  windows        36
# Length: 149, dtype: int64

# %%
agg_counts = by_tz_os.size().unstack() # make it into 2-way relational data table

# %%
by_tz_os.size().unstack().fillna(0) # and also replace NaN to 0
# Out:
#                                 Not Windows  windows
# tz
#                                         245      276
# Africa/Cairo                              0        3
# Africa/Casablanca                         0        1
# Africa/Ceuta                              0        2
# Africa/Johannesburg                       0        1
# Africa/Lusaka                             0        1
# America/Anchorage                         4        1
# America/Argentina/Buenos_Aires            1        0
# America/Argentina/Cordoba                 0        1
# America/Argentina/Mendoza                 0        1
# America/Bogota                            1        2
# America/Caracas                           0        1
# America/Chicago                         115      285
# America/Chihuahua                         1        1
# America/Costa_Rica                        0        1
# America/Denver                          132       59
# America/Edmonton                          2        4
# America/Guayaquil                         2        0
# America/Halifax                           1        3
# America/Indianapolis                      8       12
# America/La_Paz                            0        1
# America/Lima                              0        1
# America/Los_Angeles                     130      252
# America/Managua                           0        3
# America/Mazatlan                          1        0
# America/Mexico_City                       7        8
# America/Monterrey                         1        0
# America/Montevideo                        0        1
# America/Montreal                          3        6
# America/New_York                        339      912
# America/Phoenix                           3       17
# America/Puerto_Rico                       9        1
# America/Rainy_River                      10       15
# America/Recife                            0        2
# America/Santo_Domingo                     1        0
# America/Sao_Paulo                        13       20
# America/St_Kitts                          1        0
# America/Tegucigalpa                       0        1
# America/Vancouver                         6        6
# America/Winnipeg                          3        1
# Asia/Amman                                0        2
# Asia/Bangkok                              0        6
# Asia/Beirut                               1        3
# Asia/Calcutta                             2        7
# Asia/Dubai                                2        2
# Asia/Harbin                               0        3
# Asia/Hong_Kong                            4        6
# Asia/Istanbul                             0        9
# Asia/Jakarta                              2        1
# Asia/Jerusalem                            2        1
# Asia/Karachi                              0        3
# Asia/Kuala_Lumpur                         1        2
# Asia/Kuching                              0        1
# Asia/Manila                               0        1
# Asia/Nicosia                              0        1
# Asia/Novosibirsk                          0        1
# Asia/Pontianak                            1        0
# Asia/Riyadh                               0        1
# Asia/Seoul                                4        1
# Asia/Tokyo                                2       35
#                                         ...      ...
#
# [97 rows x 2 columns]

# %%
indexer = agg_counts.sum(1).argsort() # so this is like piping in command shells. sum over 2nd index = OS

# %%
indexer[:10]
# Out:
# tz
#                                   24
# Africa/Cairo                      20
# Africa/Casablanca                 21
# Africa/Ceuta                      92
# Africa/Johannesburg               87
# Africa/Lusaka                     53
# America/Anchorage                 54
# America/Argentina/Buenos_Aires    57
# America/Argentina/Cordoba         26
# America/Argentina/Mendoza         55
# dtype: int64

# %%
type(agg_counts)
# Out:
# pandas.core.frame.DataFrame

# %%
count_subset = agg_counts.take(indexer)[-10:]

# %%
print count_subset
# Out:
#                      Not Windows  windows
# tz
# America/Sao_Paulo             13       20
# Europe/Madrid                 16       19
# Pacific/Honolulu             NaN       36
# Asia/Tokyo                     2       35
# Europe/London                 43       31
# America/Denver               132       59
# America/Los_Angeles          130      252
# America/Chicago              115      285
#                              245      276
# America/New_York             339      912
#
# [10 rows x 2 columns]

# %%
count_subset = count_subset.fillna(0)
print count_subset=
# Out:
#                      Not Windows  windows
# tz
# America/Sao_Paulo             13       20
# Europe/Madrid                 16       19
# Pacific/Honolulu               0       36
# Asia/Tokyo                     2       35
# Europe/London                 43       31
# America/Denver               132       59
# America/Los_Angeles          130      252
# America/Chicago              115      285
#                              245      276
# America/New_York             339      912
#
# [10 rows x 2 columns]

# %%
count_subset.plot(kind='bar', stacked=True) # might be a DataFrame method for plotting. What a nice "DATA ANALYSIS" library!!

# %%
normed_subset = count_subset.div(count_subset.sum(1), axis=0) # so divide table elements for first axis, element-wise
normed_subset.plot(kind='bar', stacked=True)
